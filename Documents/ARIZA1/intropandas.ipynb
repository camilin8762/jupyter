# %%
import pandas as pd

data=pd.read_csv('empleados.csv')

data.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %%
data.dtypes
# Out:
# EMPLOYEE_ID        int64
# FIRST_NAME        object
# LAST_NAME         object
# EMAIL             object
# PHONE_NUMBER      object
# HIRE_DATE         object
# JOB_ID            object
# SALARY             int64
# COMMISSION_PCT    object
# MANAGER_ID        object
# DEPARTMENT_ID      int64
# dtype: object

# %%
data_2=pd.read_json('employees.json')

data_2.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %%
data_3=pd.read_excel('chicos.xlsx')

data_3.head()
# Out:
#    Id Aprendiz         Nombres       Apellidos
# 0            1    Valery Sofia    Diaz Vasquez
# 1            2        Leonardo      Lopez Rios
# 2            3     Juan Camilo     Gomez Rueda
# 3            4  Kevin Santiago  Rodriguez Paez
# 4            5   Jesus Alfredo  Rodriguez Diaz

# %%
data.tail()
# Out:
#     EMPLOYEE_ID FIRST_NAME   LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 45          136      Hazel  Philtanker  HPHILTAN  650.127.1634  06-FEB-08
# 46          137     Renske      Ladwig   RLADWIG  650.121.1234  14-JUL-03
# 47          138    Stephen      Stiles   SSTILES  650.121.2034  26-OCT-05
# 48          139       John         Seo      JSEO  650.121.2019  12-FEB-06
# 49          140     Joshua       Patel    JPATEL  650.121.1834  06-APR-06
#
#       JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 45  ST_CLERK    2200             -         122             50
# 46  ST_CLERK    3600             -         123             50
# 47  ST_CLERK    3200             -         123             50
# 48  ST_CLERK    2700             -         123             50
# 49  ST_CLERK    2500             -         123             50

# %%
data.columns
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'SALARY', 'COMMISSION_PCT', 'MANAGER_ID',
#        'DEPARTMENT_ID'],
#       dtype='object')

# %%
data.to_numpy()
# Out:
# array([[198, 'Donald', 'OConnell', 'DOCONNEL', '650.507.9833',
#         '21-JUN-07', 'SH_CLERK', 2600, ' - ', '124', 50],
#        [199, 'Douglas', 'Grant', 'DGRANT', '650.507.9844', '13-JAN-08',
#         'SH_CLERK', 2600, ' - ', '124', 50],
#        [200, 'Jennifer', 'Whalen', 'JWHALEN', '515.123.4444',
#         '17-SEP-03', 'AD_ASST', 4400, ' - ', '101', 10],
#        [201, 'Michael', 'Hartstein', 'MHARTSTE', '515.123.5555',
#         '17-FEB-04', 'MK_MAN', 13000, ' - ', '100', 20],
#        [202, 'Pat', 'Fay', 'PFAY', '603.123.6666', '17-AUG-05', 'MK_REP',
#         6000, ' - ', '201', 20],
#        [203, 'Susan', 'Mavris', 'SMAVRIS', '515.123.7777', '07-JUN-02',
#         'HR_REP', 6500, ' - ', '101', 40],
#        [204, 'Hermann', 'Baer', 'HBAER', '515.123.8888', '07-JUN-02',
#         'PR_REP', 10000, ' - ', '101', 70],
#        [205, 'Shelley', 'Higgins', 'SHIGGINS', '515.123.8080',
#         '07-JUN-02', 'AC_MGR', 12008, ' - ', '101', 110],
# ...

# %%
data.describe()
# Out:
#        EMPLOYEE_ID        SALARY  DEPARTMENT_ID
# count    50.000000     50.000000       50.00000
# mean    134.760000   6182.320000       57.60000
# std      33.631594   4586.181772       25.11687
# min     100.000000   2100.000000       10.00000
# 25%     112.250000   2725.000000       50.00000
# 50%     124.500000   4600.000000       50.00000
# 75%     136.750000   8150.000000       60.00000
# max     206.000000  24000.000000      110.00000

# %%
data_4=pd.read_csv('datset.csv')

data_4
# Out:
#        ORDEN        CLASE            MARCA  MODELO FECHA MATRICULA/RADICACION  \
# 0          1  MOTOCICLETA           YAMAHA    2000                 02/02/2000
# 1          2  MOTOCICLETA           SUZUKI    2000                 23/02/2000
# 2          3  MOTOCICLETA  AUTECO KAWASAKI    2000                 25/09/2000
# 3          4    AUTOMOVIL          RENAULT    1988                 18/09/2000
# 4          5    CAMIONETA        CHEVROLET    1988                 24/03/2000
# ...      ...          ...              ...     ...                        ...
# 16938  16939  MOTOCICLETA            BAJAJ    2022                 21/01/2022
# 16939  16940  MOTOCICLETA          VICTORY    2022                 27/01/2022
# 16940  16941  MOTOCICLETA            BAJAJ    2022                 25/01/2022
# 16941  16942  MOTOCICLETA            BAJAJ    2022                 28/01/2022
# 16942  16943  MOTOCICLETA              AKT    2022                 10/02/2022
#
# ...

# %%
data_4.dtypes
# Out:
# ORDEN                          int64
# CLASE                         object
# MARCA                         object
# MODELO                         int64
# FECHA MATRICULA/RADICACION    object
# AÑO                            int64
# MES                           object
# DIA                           object
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 data.index()
#
# TypeError: 'RangeIndex' object is not callable
