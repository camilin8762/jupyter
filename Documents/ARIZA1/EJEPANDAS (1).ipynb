# %%
import pandas as pd

# %%
data_csv = pd.read_csv("employees.csv")
data_csv.head(7) # nos da las 5 primeras filas
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
# 5          203      Susan     Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6          204    Hermann       Baer     HBAER  515.123.8888  07-JUN-02
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20
# ...

# %%
data_csv.dtypes # nos da los tipos de datos de cada encabezado
# Out:
# EMPLOYEE_ID        int64
# FIRST_NAME        object
# LAST_NAME         object
# EMAIL             object
# PHONE_NUMBER      object
# HIRE_DATE         object
# JOB_ID            object
# SALARY             int64
# COMMISSION_PCT    object
# MANAGER_ID        object
# DEPARTMENT_ID      int64
# dtype: object

# %%
data_csv.tail() # nos da los ultimos datos
# Out:
#     EMPLOYEE_ID FIRST_NAME   LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 45          136      Hazel  Philtanker  HPHILTAN  650.127.1634  06-FEB-08
# 46          137     Renske      Ladwig   RLADWIG  650.121.1234  14-JUL-03
# 47          138    Stephen      Stiles   SSTILES  650.121.2034  26-OCT-05
# 48          139       John         Seo      JSEO  650.121.2019  12-FEB-06
# 49          140     Joshua       Patel    JPATEL  650.121.1834  06-APR-06
#
#       JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 45  ST_CLERK    2200             -         122             50
# 46  ST_CLERK    3600             -         123             50
# 47  ST_CLERK    3200             -         123             50
# 48  ST_CLERK    2700             -         123             50
# 49  ST_CLERK    2500             -         123             50

# %%
data_csv.columns # nos trae las columnas
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'SALARY', 'COMMISSION_PCT', 'MANAGER_ID',
#        'DEPARTMENT_ID'],
#       dtype='object')

# %%
data_csv.to_numpy() # nos transforma el archivo a un arreglo numpy
# Out:
# array([[198, 'Donald', 'OConnell', 'DOCONNEL', '650.507.9833',
#         '21-JUN-07', 'SH_CLERK', 2600, ' - ', '124', 50],
#        [199, 'Douglas', 'Grant', 'DGRANT', '650.507.9844', '13-JAN-08',
#         'SH_CLERK', 2600, ' - ', '124', 50],
#        [200, 'Jennifer', 'Whalen', 'JWHALEN', '515.123.4444',
#         '17-SEP-03', 'AD_ASST', 4400, ' - ', '101', 10],
#        [201, 'Michael', 'Hartstein', 'MHARTSTE', '515.123.5555',
#         '17-FEB-04', 'MK_MAN', 13000, ' - ', '100', 20],
#        [202, 'Pat', 'Fay', 'PFAY', '603.123.6666', '17-AUG-05', 'MK_REP',
#         6000, ' - ', '201', 20],
#        [203, 'Susan', 'Mavris', 'SMAVRIS', '515.123.7777', '07-JUN-02',
#         'HR_REP', 6500, ' - ', '101', 40],
#        [204, 'Hermann', 'Baer', 'HBAER', '515.123.8888', '07-JUN-02',
#         'PR_REP', 10000, ' - ', '101', 70],
#        [205, 'Shelley', 'Higgins', 'SHIGGINS', '515.123.8080',
#         '07-JUN-02', 'AC_MGR', 12008, ' - ', '101', 110],
# ...

# %%
data_csv.describe() # Nos saca promedios estadisticos basicos
# Out:
#        EMPLOYEE_ID        SALARY  DEPARTMENT_ID
# count    50.000000     50.000000       50.00000
# mean    134.760000   6182.320000       57.60000
# std      33.631594   4586.181772       25.11687
# min     100.000000   2100.000000       10.00000
# 25%     112.250000   2725.000000       50.00000
# 50%     124.500000   4600.000000       50.00000
# 75%     136.750000   8150.000000       60.00000
# max     206.000000  24000.000000      110.00000

# %%
data_csv.T # Cambia de pocision las filas y columnas
# Out:
#                           0             1             2             3   \
# EMPLOYEE_ID              198           199           200           201
# FIRST_NAME            Donald       Douglas      Jennifer       Michael
# LAST_NAME           OConnell         Grant        Whalen     Hartstein
# EMAIL               DOCONNEL        DGRANT       JWHALEN      MHARTSTE
# PHONE_NUMBER    650.507.9833  650.507.9844  515.123.4444  515.123.5555
# HIRE_DATE          21-JUN-07     13-JAN-08     17-SEP-03     17-FEB-04
# JOB_ID              SH_CLERK      SH_CLERK       AD_ASST        MK_MAN
# SALARY                  2600          2600          4400         13000
# COMMISSION_PCT            -             -             -             -
# MANAGER_ID               124           124           101           100
# DEPARTMENT_ID             50            50            10            20
#
#                           4             5             6             7   \
# ...

# %%
data_csv.sort_index(axis=1, ascending=False) # Nos pone las columnas organizadas al contrario
# Out:
#     SALARY  PHONE_NUMBER MANAGER_ID    LAST_NAME      JOB_ID  HIRE_DATE  \
# 0     2600  650.507.9833        124     OConnell    SH_CLERK  21-JUN-07
# 1     2600  650.507.9844        124        Grant    SH_CLERK  13-JAN-08
# 2     4400  515.123.4444        101       Whalen     AD_ASST  17-SEP-03
# 3    13000  515.123.5555        100    Hartstein      MK_MAN  17-FEB-04
# 4     6000  603.123.6666        201          Fay      MK_REP  17-AUG-05
# 5     6500  515.123.7777        101       Mavris      HR_REP  07-JUN-02
# 6    10000  515.123.8888        101         Baer      PR_REP  07-JUN-02
# 7    12008  515.123.8080        101      Higgins      AC_MGR  07-JUN-02
# 8     8300  515.123.8181        205        Gietz  AC_ACCOUNT  07-JUN-02
# 9    24000  515.123.4567         -          King     AD_PRES  17-JUN-03
# 10   17000  515.123.4568        100      Kochhar       AD_VP  21-SEP-05
# 11   17000  515.123.4569        100      De Haan       AD_VP  13-JAN-01
# ...

# %%
data_csv.sort_values(by="FIRST_NAME") #ordena ALFABETICAMENTE DEACUERDO A LA COUMNA
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 30          121         Adam        Fripp    AFRIPP  650.123.2234  10-APR-05
# 24          115    Alexander         Khoo     AKHOO  515.127.4562  18-MAY-03
# 12          103    Alexander       Hunold   AHUNOLD  590.423.4567  03-JAN-06
# 13          104        Bruce        Ernst    BERNST  590.423.4568  21-MAY-07
# 18          109       Daniel       Faviet   DFAVIET  515.124.4169  16-AUG-02
# 14          105        David       Austin   DAUSTIN  590.423.4569  25-JUN-05
# 23          114          Den     Raphaely  DRAPHEAL  515.127.4561  07-DEC-02
# 16          107        Diana      Lorentz  DLORENTZ  590.423.5567  07-FEB-07
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 27          118          Guy       Himuro   GHIMURO  515.127.4565  15-NOV-06
# ...

# %%
data_csv["PHONE_NUMBER"]#llama solo esa columna y dice el tipo de dato
# Out:
# 0     650.507.9833
# 1     650.507.9844
# 2     515.123.4444
# 3     515.123.5555
# 4     603.123.6666
# 5     515.123.7777
# 6     515.123.8888
# 7     515.123.8080
# 8     515.123.8181
# 9     515.123.4567
# 10    515.123.4568
# 11    515.123.4569
# 12    590.423.4567
# 13    590.423.4568
# 14    590.423.4569
# 15    590.423.4560
# 16    590.423.5567
# 17    515.124.4569
# 18    515.124.4169
# 19    515.124.4269
# 20    515.124.4369
# 21    515.124.4469
# 22    515.124.4567
# 23    515.127.4561
# 24    515.127.4562
# 25    515.127.4563
# 26    515.127.4564
# 27    515.127.4565
# 28    515.127.4566
# 29    650.123.1234
# 30    650.123.2234
# 31    650.123.3234
# 32    650.123.4234
# 33    650.123.5234
# 34    650.124.1214
# 35    650.124.1224
# 36    650.124.1334
# 37    650.124.1434
# 38    650.124.5234
# 39    650.124.6234
# 40    650.124.7234
# 41    650.124.8234
# 42    650.127.1934
# 43    650.127.1834
# 44    650.127.1734
# 45    650.127.1634
# 46    650.121.1234
# ...

# %%
data_csv[:3]# toma la cantidada de filas deseadas
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald  OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas     Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer    Whalen   JWHALEN  515.123.4444  17-SEP-03
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10

# %%
data_csv[1:6] # hace recorte a las filas que queremos ver "rebanadas"
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
# 5          203      Susan     Mavris   SMAVRIS  515.123.7777  07-JUN-02
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20
# 5    HR_REP    6500             -         101             40

# %%
data_csv.loc[:,["EMPLOYEE_ID","EMAIL"]] #toma las columnas deseadas y las filas que deseemos
# Out:
#     EMPLOYEE_ID     EMAIL
# 0           198  DOCONNEL
# 1           199    DGRANT
# 2           200   JWHALEN
# 3           201  MHARTSTE
# 4           202      PFAY
# 5           203   SMAVRIS
# 6           204     HBAER
# 7           205  SHIGGINS
# 8           206    WGIETZ
# 9           100     SKING
# 10          101  NKOCHHAR
# 11          102   LDEHAAN
# 12          103   AHUNOLD
# 13          104    BERNST
# 14          105   DAUSTIN
# 15          106  VPATABAL
# 16          107  DLORENTZ
# 17          108  NGREENBE
# 18          109   DFAVIET
# 19          110     JCHEN
# 20          111  ISCIARRA
# 21          112   JMURMAN
# 22          113     LPOPP
# 23          114  DRAPHEAL
# 24          115     AKHOO
# 25          116    SBAIDA
# 26          117   STOBIAS
# 27          118   GHIMURO
# 28          119  KCOLMENA
# 29          120    MWEISS
# 30          121    AFRIPP
# 31          122  PKAUFLIN
# 32          123  SVOLLMAN
# 33          124  KMOURGOS
# ...

# %%
data_csv.loc[5:15 ,["EMPLOYEE_ID","EMAIL"]] # 5 a 15, de esas dos colunnas
# Out:
#     EMPLOYEE_ID     EMAIL
# 5           203   SMAVRIS
# 6           204     HBAER
# 7           205  SHIGGINS
# 8           206    WGIETZ
# 9           100     SKING
# 10          101  NKOCHHAR
# 11          102   LDEHAAN
# 12          103   AHUNOLD
# 13          104    BERNST
# 14          105   DAUSTIN
# 15          106  VPATABAL

# %%
data_csv.loc[6,["LAST_NAME","HIRE_DATE"]]# saca los datos que queremos saber de una fila
# Out:
# LAST_NAME         Baer
# HIRE_DATE    07-JUN-02
# Name: 6, dtype: object

# %%
data_csv.iloc[4]# trae todos los datos de la fila que queramos
# Out:
# EMPLOYEE_ID                202
# FIRST_NAME                 Pat
# LAST_NAME                  Fay
# EMAIL                     PFAY
# PHONE_NUMBER      603.123.6666
# HIRE_DATE            17-AUG-05
# JOB_ID                  MK_REP
# SALARY                    6000
# COMMISSION_PCT              -
# MANAGER_ID                 201
# DEPARTMENT_ID               20
# Name: 4, dtype: object

# %%
data_csv.iloc[3:5,0:2]# toma posiciones de filas y columnas
# Out:
#    EMPLOYEE_ID FIRST_NAME
# 3          201    Michael
# 4          202        Pat

# %%
data_csv.iloc[[1,2,4],[0,2]]#llama posiciones de filas y columnas exactas
# Out:
#    EMPLOYEE_ID LAST_NAME
# 1          199     Grant
# 2          200    Whalen
# 4          202       Fay

# %%
data_csv.iloc[1:3,:]#filas 1 y 2 toma todos los datos de la fila
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME    EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 1          199    Douglas     Grant   DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer    Whalen  JWHALEN  515.123.4444  17-SEP-03
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10

# %%
data_csv.iloc[:,1:3] # lee todas las filas de la columna 1 a la tres osea la dos
# Out:
#      FIRST_NAME    LAST_NAME
# 0        Donald     OConnell
# 1       Douglas        Grant
# 2      Jennifer       Whalen
# 3       Michael    Hartstein
# 4           Pat          Fay
# 5         Susan       Mavris
# 6       Hermann         Baer
# 7       Shelley      Higgins
# 8       William        Gietz
# 9        Steven         King
# 10        Neena      Kochhar
# 11          Lex      De Haan
# 12    Alexander       Hunold
# 13        Bruce        Ernst
# 14        David       Austin
# 15        Valli    Pataballa
# 16        Diana      Lorentz
# 17        Nancy    Greenberg
# 18       Daniel       Faviet
# 19         John         Chen
# 20       Ismael      Sciarra
# 21  Jose Manuel        Urman
# 22         Luis         Popp
# 23          Den     Raphaely
# 24    Alexander         Khoo
# 25       Shelli        Baida
# 26        Sigal       Tobias
# 27          Guy       Himuro
# 28        Karen   Colmenares
# 29      Matthew        Weiss
# 30         Adam        Fripp
# ...
